# %%
import numpy as np
import scipy.signal as ss
from PIL import Image as Img
import matplotlib.pyplot as plt
import cv2
import math

# %%
def filter(img):
    ## return original image
    return img

# %%
im1 = Img.open("birds1.jpeg")
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
fig.tight_layout()
axs[0].imshow(im1)
axs[0].set_title('original', fontsize=10)
axs[1].imshow(filter(im1))
axs[1].set_title('filtered', fontsize=10)
# Out:
# Text(0.5, 1.0, 'filtered')

# %%
im1 = Img.open("birds2.jpeg")
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
fig.tight_layout()
axs[0].imshow(im1)
axs[0].set_title('original', fontsize=10)
axs[1].imshow(filter(im1))
axs[1].set_title('filtered', fontsize=10)
# Out:
# Text(0.5, 1.0, 'filtered')

# %%
im1 = Img.open("lane.png")
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
fig.tight_layout()
axs[0].imshow(im1)
axs[0].set_title('original', fontsize=10)
axs[1].imshow(filter(im1))
axs[1].set_title('filtered', fontsize=10)
# Out:
# Text(0.5, 1.0, 'filtered')
